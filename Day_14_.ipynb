# %% [markdown]
# <a href="https://colab.research.google.com/github/maniprasad84/2311cs020450/blob/main/Day_14_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['sex', 'smoker', 'day', 'time'],)"
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
pip install seaborn

# %%
df = sns.load_dataset("tips")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
print(df.columns)
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.barplot(x='day', y='total_bill', data=df, color='red')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.histplot(x=df['tip'],color='blue')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.boxplot(x=df['tip'])
# Out:
# <Axes: xlabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip', data=df, palette=['green','red'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.stripplot(x='sex', y='tip', data=df, palette=['green','red'])
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
iris_data=sns.load_dataset("iris")
df=sns.load_dataset("taxis")

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.scatterplot(x=iris_data['sepal_length'], y=iris_data['petal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x=iris_data['sepal_length'], y=iris_data['petal_length'],hue=iris_data['species'],palette=['red','green','yellow'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.stripplot(x=df['payment'], y=df['total'],palette=['red','green','yellow'])
# Out:
# <Axes: xlabel='payment', ylabel='total'>

# %%
sns.stripplot(x=df['payment'], y=df['tip'],palette=['red','green'])
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %%
sns.lineplot(x=df['tip'], y=df['fare'])
# Out:
# <Axes: xlabel='tip', ylabel='fare'>

# %%
sns.lineplot(x=df['total'], y=df['fare'],hue=df['payment'])
# Out:
# <Axes: xlabel='total', ylabel='fare'>

# %%
sns.lineplot(x=df['tip'], y=df['fare'],hue=df['payment'],hue=df['payment'],palette=['red','orange'])
# Out:
#   File "<ipython-input-14-4561b08d5ce2>", line 1
#     sns.lineplot(x=df['tip'], y=df['fare'],hue=df['payment'],hue=df['payment'],palette=['red','orange'])
#                                                              ^
# SyntaxError: keyword argument repeated: hue

# %%
df[['payment','color']].value_counts()
# Out:
# payment      color
# credit card  yellow    4000
# cash         yellow    1412
# credit card  green      577
# cash         green      400
# Name: count, dtype: int64

# %%
df[['color']].value_counts()
# Out:
# color
# yellow    5451
# green      982
# Name: count, dtype: int64

# %%
df[['payment']].value_counts()
# Out:
# payment
# credit card    4577
# cash           1812
# Name: count, dtype: int64

# %%
sns.countplot(x=df['payment'])
# Out:
# <Axes: xlabel='payment', ylabel='count'>

# %%
plt.figure(figsize=(2,2))
sns.countplot(x=df['payment'],hue=df['color'],palette=['lightgreen','yellow'])
plt.xlabel('payment Mode',fontsize=20)
# Out:
# Text(0.5, 0, 'payment Mode')
